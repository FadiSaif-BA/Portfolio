# %%
import importlib
import transliterate

# Reload the module
importlib.reload(transliterate)

from transliterate import YemenPlaceTransliterator

transliterator = YemenPlaceTransliterator()

transliterator.process_csv(
    input_file=r'data\yemen_admin_areas.csv',
    output_file=r'data\yemen_admin_areas_transliterated.csv',
    arabic_column='place_name'
)
# Out:
# Loading morphology database...
# Ready!
# Reading data\yemen_admin_areas.csv...
# Found 14 place names
#
# ✓ Processing complete! Saved to data\yemen_admin_areas_transliterated.csv
#   Successful: 14/14
#
# Sample results:
#   الشيخ عثمان → Al-Shaykh Uthman
#   الطريّة → Al-Taryyaa
#   الوضيع → Al-Wadi'
#   الصبَّيحة → Al-Sabayha
#   وادي حضرموت → Wadi Hadramawt
#   دار المناصرة → Dar Al-Munasiraa
#   شعب العيدروس → Sha'b Al-Aidaroos
#   المظفر → Al-Mudhaffar
#   الضالع → Al-Dali'
#   المضاربة و رأس العارة → Al-Mudaribaa W Ras Al-'ara
