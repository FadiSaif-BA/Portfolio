# %%
import pandas as pd
from datetime import datetime
import sys

# %%
# Load the Excel file
df = pd.read_excel('Irrigation_DS.xlsx')

# %%
print("=" * 80)
print("BEFORE RENAMING:")
print("=" * 80)
print(f"Total columns: {len(df.columns)}")
print(f"Total rows: {len(df)}\n")
# Out:
# ================================================================================
# BEFORE RENAMING:
# ================================================================================
# Total columns: 70
# Total rows: 30

# %%
# Create a comprehensive column mapping - Concise yet Elaborative
column_mapping = {
    'start': 'Survey_Start_Time',
    'end': 'Survey_End_Time',
    'اسم الماسح:': 'Surveyor_Name',
    'تاريخ المسح': 'Survey_Date',
    'المحافظة': 'Governorate',
    'المحافظة: لحج': 'Governorate_Lahj',
    'القرية': 'Village_Name',
    'اسم المستفيد': 'Beneficiary_Name',
    'اسم المستجيب': 'Respondent_Name',
    ' Type of Irrigation system': 'Irrigation_System_Type',
    'Type of crop growing': 'Crop_Type',
    
    # SECTION 1: Land Preparation
    ' اولا: اعداد الارض:(ساعات*اجرة) ': 'Land_Prep_Section_Header',
    'total cost take to plow the area of \u200b\u200b one acre connected to the meter?': 'Land_Prep_Plowing_Cost_Per_Acre',
    'total cost take to settle the area of one acre': 'Land_Prep_Settlement_Cost_Per_Acre',
    'total cost take to divide the area of \u200b\u200bone acre connected to the meter?': 'Land_Prep_Division_Cost_Per_Acre',
    'total cost take to terrace the area of one acre connected to the meter?': 'Land_Prep_Terracing_Cost_Per_Acre',
    'total_cost': 'Land_Prep_Total_Cost',
    'How many workers were needed to raise the terracing and canals ': 'Land_Prep_Workers_Count',
    'How much was the wage of a worker per day per acre connected to the meter': 'Land_Prep_Worker_Wage_Per_Day',
    'How many days were needed to work on this acre?': 'Land_Prep_Working_Days',
    'total cost of worker to prepare the land': 'Land_Prep_Labor_Total_Cost',
    'Total cost of Land prepare': 'Land_Prep_Grand_Total_Cost',
    
    # SECTION 2: Nursery/Seedling Preparation
    '  ثانيا: اعداد المشتل  ': 'Nursery_Prep_Section_Header',
    'total cost of seeding preparing': 'Nursery_Prep_Total_Cost',
    
    # SECTION 3: Permanent Land Cultivation
    'ثالثا: زراعة الارض المستديمة: *يتم اجراء هذا المسح في الشهر الاول و الثاني': 'Cultivation_Section_Header',
    'How many labors were needed to cultivate one acre of …………………… (tomatoes / onions / green jalapino / Leafy plants / okra) ': 'Cultivation_Laborers_Count',
    'How much was the cost of seeds / seedlings planted per acre: The amount of seeds (Quantity)': 'Cultivation_Seeds_Quantity',
    'How much was the wage of a worker per day?': 'Cultivation_Worker_Wage_Per_Day',
    'The cost of the worker in cultivating sustainable land': 'Cultivation_Labor_Total_Cost',
    
    # SECTION 4: Fertilization
    'Fertilization': 'Fertilization_Section_Header',
    'How much was the cost of the fertilizer you used in the one acer connected to the meter? (Quantity in kg)': 'Fertilizer_Quantity_Kg',
    'How much was the cost of the fertilizer you used in the one acer connected to the meter? (Cost (YER))': 'Fertilizer_Cost_YER',
    'Total cost of fertilizer ': 'Fertilizer_Total_Cost',
    
    # SECTION 5: Production and Harvest
    'خامسا: Quantity of production and harvest': 'Production_Section_Header',
    'Quantity of production in the last cultivation season (number of baskets / kg)': 'Production_Quantity_Baskets_Kg',
    'How many times did you harvest the planted items in the last month? ': 'Production_Harvest_Frequency_Per_Month',
    'الكلفة العامة لكمية المحصول': 'Production_Total_Harvest_Cost',
    'cost of  production and harvest': 'Production_Harvest_Labor_Cost',
    
    # SECTION 6: Production Cost
    'سادسا: Cost of production: ': 'Production_Cost_Section_Header',
    'How much was the final production cost needed for harvesting in YER': 'Production_Final_Harvest_Cost_YER',
    
    # SECTION 7: Pest Control
    'سابعا:Pest Control': 'Pest_Control_Section_Header',
    ' ماهو نوع المكافحة المستخدمة': 'Pest_Control_Type',
    ' ماهو نوع المكافحة المستخدمة/مكافحة حيوية (استخدام الاعداء الطبيعية منها: المفترسات و المتطفلات مثل النمل)': 'Pest_Control_Biological',
    ' ماهو نوع المكافحة المستخدمة/مكافحة ميكانيكية (جمع الحشرات الكبيرة باليد وا ستخدام التدخين واستخدام المصائد الضوئية و الفورمونية)': 'Pest_Control_Mechanical',
    ' ماهو نوع المكافحة المستخدمة/مكافحة كيمياوية (باستخدام المبيدات)': 'Pest_Control_Chemical',
    ' ماهو نوع المكافحة المستخدمة/اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)': 'Pest_Control_Other',
    'If the answer (chemical control) how much was the cost of its materials:': 'Pest_Control_Chemical_Materials_Cost',
    'How many workers were needed?': 'Pest_Control_Workers_Count',
    'How much was the wage of the worker per day?': 'Pest_Control_Worker_Wage_Per_Day',
    'no. of working day': 'Pest_Control_Working_Days',
    'worker cost of pest control': 'Pest_Control_Labor_Total_Cost',
    'Total cost of Pest control': 'Pest_Control_Grand_Total_Cost',
    
    # SECTION 8: Water Consumption
    ' ثامنا: Amount of water consumed': 'Water_Consumption_Section_Header',
    'Record the meters reading': 'Water_Meter_Reading',
    'How many hours the water pumped in one irrigation time?': 'Water_Pumping_Hours_Per_Irrigation',
    'How many times the land was irrigated in the last month?': 'Water_Irrigation_Frequency_Per_Month',
    'Hr*time per month/6*20': 'Water_Calculated_Hours_Per_Month',
    'cost of desile': 'Water_Diesel_Cost',
    'no of worker needed to irrigate the land': 'Water_Workers_Count',
    'wage of worker per day': 'Water_Worker_Wage_Per_Day',
    'no of days per month': 'Water_Working_Days_Per_Month',
    'total cost of worker': 'Water_Labor_Total_Cost',
    'Total cost of water and diesel consumption': 'Water_Grand_Total_Cost',
    
    # Additional Water/Diesel Info
    '      ': 'Water_Additional_Info_Spacer',
    'What is the applied pumping mechanism': 'Water_Pumping_Mechanism_Type',
    'The number of hours were needed to operate the engine to irrigate the acre per day:': 'Water_Engine_Hours_Per_Acre_Per_Day',
    'What was the amount of diesel spent to irrigate the area of the acre in the last month?': 'Water_Diesel_Quantity_Last_Month',
    'How much was the cost of diesel spent in the last month?': 'Water_Diesel_Cost_Last_Month',
    
    # Other
    'ملاحظات الماسح': 'Surveyor_Notes',
    '_index': 'Record_Index'
}

# %%
# Apply the renaming
df_renamed = df.rename(columns=column_mapping)

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 70 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   survey_start_time                       30 non-null     object
#  1   survey_end_time                         30 non-null     object
#  2   surveyor_name                           30 non-null     object
#  3   survey_date                             30 non-null     object
#  4   governorate                             30 non-null     object
#  5   governorate_lahj                        30 non-null     object
#  6   village_name                            30 non-null     object
#  7   beneficiary_name                        30 non-null     object
#  8   respondent_name                         30 non-null     object
#  9   irrigation_system_type                  30 non-null     object
#  10  crop_type                               30 non-null     object
#  11  land_prep_section_header                30 non-null     object
#  12  land_prep_plowing_cost_per_acre         30 non-null     int64
#  13  land_prep_settlement_cost_per_acre      30 non-null     int64
#  14  land_prep_division_cost_per_acre        30 non-null     int64
#  15  land_prep_terracing_cost_per_acre       30 non-null     int64
#  16  land_prep_total_cost                    30 non-null     int64
#  17  land_prep_workers_count                 30 non-null     int64
#  18  land_prep_worker_wage_per_day           30 non-null     int64
#  19  land_prep_working_days                  30 non-null     int64
#  20  land_prep_labor_total_cost              30 non-null     int64
#  21  land_prep_grand_total_cost              30 non-null     int64
#  22  nursery_prep_section_header             30 non-null     object
#  23  nursery_prep_total_cost                 30 non-null     int64
#  24  cultivation_section_header              30 non-null     object
#  25  cultivation_laborers_count              30 non-null     int64
#  26  cultivation_seeds_quantity              30 non-null     int64
#  27  cultivation_worker_wage_per_day         30 non-null     int64
#  28  cultivation_labor_total_cost            30 non-null     int64
#  29  fertilization_section_header            30 non-null     object
#  30  fertilizer_quantity_kg                  30 non-null     int64
#  31  fertilizer_cost_yer                     30 non-null     int64
#  32  fertilizer_total_cost                   30 non-null     int64
#  33  production_section_header               30 non-null     object
#  34  production_quantity_baskets_kg          28 non-null     float64
#  35  production_harvest_frequency_per_month  28 non-null     float64
#  36  production_total_harvest_cost           30 non-null     int64
#  37  production_harvest_labor_cost           30 non-null     int64
#  38  production_cost_section_header          30 non-null     object
#  39  production_final_harvest_cost_yer       28 non-null     float64
#  40  pest_control_section_header             30 non-null     object
#  41  pest_control_type                       30 non-null     object
#  42  pest_control_biological                 30 non-null     int64
#  43  pest_control_mechanical                 30 non-null     int64
#  44  pest_control_chemical                   30 non-null     int64
#  45  pest_control_other                      30 non-null     int64
#  46  pest_control_chemical_materials_cost    19 non-null     float64
#  47  pest_control_workers_count              30 non-null     int64
#  48  pest_control_worker_wage_per_day        30 non-null     int64
#  49  pest_control_working_days               30 non-null     int64
#  50  pest_control_labor_total_cost           30 non-null     int64
#  51  pest_control_grand_total_cost           30 non-null     int64
#  52  water_consumption_section_header        30 non-null     object
#  53  water_meter_reading                     30 non-null     int64
#  54  water_pumping_hours_per_irrigation      30 non-null     int64
#  55  water_irrigation_frequency_per_month    30 non-null     int64
#  56  water_calculated_hours_per_month        30 non-null     float64
#  57  water_diesel_cost                       30 non-null     int64
#  58  water_workers_count                     30 non-null     int64
#  59  water_worker_wage_per_day               30 non-null     int64
#  60  water_working_days_per_month            30 non-null     int64
#  61  water_labor_total_cost                  30 non-null     int64
#  62  water_grand_total_cost                  30 non-null     int64
#  63  water_additional_info_spacer            30 non-null     object
#  64  water_pumping_mechanism_type            30 non-null     object
#  65  water_engine_hours_per_acre_per_day     30 non-null     int64
#  66  water_diesel_quantity_last_month        30 non-null     int64
#  67  water_diesel_cost_last_month            30 non-null     int64
#  68  surveyor_notes                          30 non-null     object
#  69  record_index                            30 non-null     int64
# dtypes: float64(5), int64(42), object(23)
# memory usage: 16.5+ KB

# %%
df.head()
# Out:
#                survey_start_time                survey_end_time surveyor_name  \
# 0  2020-01-07T23:46:15.606+03:00  2020-01-07T23:56:55.363+03:00         سيلان
# 1  2020-01-27T09:05:52.930+03:00  2020-01-28T23:22:19.978+03:00         سوزان
# 2  2020-01-08T08:54:56.638+03:00  2020-01-08T09:28:00.559+03:00         اسرار
# 3  2020-01-08T10:50:42.269+03:00  2020-01-08T11:30:17.610+03:00         اسرار
# 4  2020-01-08T10:09:23.398+03:00  2020-01-08T10:50:30.498+03:00         اسرار
#
#   survey_date governorate governorate_lahj  village_name  \
# 0  2020-01-07         لحج              تبن  كدمه عوض علي
# 1  2020-01-27         لحج              تبن       بئر فضل
# 2  2020-01-08         لحج              تبن        كوكبان
# 3  2020-01-08         لحج              تبن     هران ديان
# 4  2020-01-08         لحج              تبن       الحمراء
#
#               beneficiary_name      respondent_name irrigation_system_type  \
# 0               نبيل قائد معين       نبيل قائد معين            Traditional
# 1        مختار حيدره علي حيدره       محسن علي حيدره                   Drip
# 2          صادق محمد فضل العسر  صادق محمد فضل العسر            Traditional
# 3          قيصر سبيت ناصر سبيت  قيصر سبيت ناصر سبيت                   Drip
# 4  ارسلان عبدالله ناصر حيدرة\n  ارسلان عبدالله ناصر                   Drip
#
#    ... water_working_days_per_month water_labor_total_cost  \
# 0  ...                            4                  40000
# 1  ...                           10                  20000
# 2  ...                            7                  35000
# 3  ...                           10                  30000
# 4  ...                            8                  16000
#
#    water_grand_total_cost  water_additional_info_spacer  \
# 0                  104000                            OK
# 1                   46680                            OK
# 2                  184320                            OK
# 3                  110000                            OK
# 4                   58680                            OK
#
#    water_pumping_mechanism_type  water_engine_hours_per_acre_per_day  \
# 0                  مضخات الديزل                                   12
# 1                  مضخات الديزل                                    2
# 2                  مضخات الديزل                                   18
# 3                  مضخات الديزل                                    4
# 4                  مضخات كهرباء                                    4
#
#    water_diesel_quantity_last_month  water_diesel_cost_last_month  \
# 0                               100                         64000
# 1                                40                         16000
# 2                               280                        112000
# 3                               160                         60000
# 4                                 0                         10000
#
#                                       surveyor_notes  record_index
# 0  المحصول جيد والمزارع مثابر ونفذ جميع عمليات ال...            11
# 1  المزارع استفاد من شبكة التنقيط وزرع و وفرت تكل...            22
# 2  بدا جني المحصول والمزارع مهتم بعمليات مكافكة ا...            13
# 3            المزارع مثالي برغم الآفات الا انه يكافح            16
# 4  المزارع مثالي بدأ جني المحصول والنمو جيد المزا...            15
#
# [5 rows x 70 columns]

# %%
df.rename(columns = {'governorate_lahj': 'district'}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['survey_start_time',
#  'survey_end_time',
#  'surveyor_name',
#  'survey_date',
#  'governorate',
#  'district',
#  'village_name',
#  'beneficiary_name',
#  'respondent_name',
#  'irrigation_system_type',
#  'crop_type',
#  'land_prep_section_header',
#  'land_prep_plowing_cost_per_acre',
#  'land_prep_settlement_cost_per_acre',
#  'land_prep_division_cost_per_acre',
#  'land_prep_terracing_cost_per_acre',
#  'land_prep_total_cost',
#  'land_prep_workers_count',
#  'land_prep_worker_wage_per_day',
#  'land_prep_working_days',
#  'land_prep_labor_total_cost',
#  'land_prep_grand_total_cost',
#  'nursery_prep_section_header',
#  'nursery_prep_total_cost',
#  'cultivation_section_header',
#  'cultivation_laborers_count',
#  'cultivation_seeds_quantity',
#  'cultivation_worker_wage_per_day',
#  'cultivation_labor_total_cost',
#  'fertilization_section_header',
#  'fertilizer_quantity_kg',
#  'fertilizer_cost_yer',
#  'fertilizer_total_cost',
#  'production_section_header',
#  'production_quantity_baskets_kg',
#  'production_harvest_frequency_per_month',
#  'production_total_harvest_cost',
#  'production_harvest_labor_cost',
#  'production_cost_section_header',
#  'production_final_harvest_cost_yer',
#  'pest_control_section_header',
#  'pest_control_type',
#  'pest_control_biological',
#  'pest_control_mechanical',
#  'pest_control_chemical',
#  'pest_control_other',
#  'pest_control_chemical_materials_cost',
#  'pest_control_workers_count',
#  'pest_control_worker_wage_per_day',
#  'pest_control_working_days',
#  'pest_control_labor_total_cost',
#  'pest_control_grand_total_cost',
#  'water_consumption_section_header',
#  'water_meter_reading',
#  'water_pumping_hours_per_irrigation',
#  'water_irrigation_frequency_per_month',
#  'water_calculated_hours_per_month',
#  'water_diesel_cost',
#  'water_workers_count',
#  'water_worker_wage_per_day',
#  'water_working_days_per_month',
#  'water_labor_total_cost',
#  'water_grand_total_cost',
#  'water_additional_info_spacer',
#  'water_pumping_mechanism_type',
#  'water_engine_hours_per_acre_per_day',
#  'water_diesel_quantity_last_month',
#  'water_diesel_cost_last_month',
#  'surveyor_notes',
#  'record_index']

# %%
df['district'] = 'Tuban'

# %%
df['governorate'] = 'Lahj'

# %%
df.drop(columns=['land_prep_section_header', 'beneficiary_name', 'respondent_name', 'nursery_prep_section_header', 'fertilization_section_header', 'production_section_header', 'production_cost_section_header', 'pest_control_section_header', 'water_consumption_section_header', 'water_additional_info_spacer', 'cultivation_section_header'], inplace=True)

# %%
df.dtypes
# Out:
# survey_date                                object
# governorate                                object
# district                                   object
# village_name                               object
# irrigation_system_type                     object
# crop_type                                  object
# land_prep_plowing_cost_per_acre             int64
# land_prep_settlement_cost_per_acre          int64
# land_prep_division_cost_per_acre            int64
# land_prep_terracing_cost_per_acre           int64
# land_prep_total_cost                        int64
# land_prep_workers_count                     int64
# land_prep_worker_wage_per_day               int64
# land_prep_working_days                      int64
# land_prep_labor_total_cost                  int64
# land_prep_grand_total_cost                  int64
# nursery_prep_total_cost                     int64
# cultivation_section_header                 object
# cultivation_laborers_count                  int64
# cultivation_seeds_quantity                  int64
# cultivation_worker_wage_per_day             int64
# cultivation_labor_total_cost                int64
# fertilizer_quantity_kg                      int64
# fertilizer_cost_yer                         int64
# fertilizer_total_cost                       int64
# production_quantity_baskets_kg            float64
# production_harvest_frequency_per_month    float64
# production_total_harvest_cost               int64
# production_harvest_labor_cost               int64
# production_final_harvest_cost_yer         float64
# pest_control_type                          object
# pest_control_biological                     int64
# pest_control_mechanical                     int64
# pest_control_chemical                       int64
# pest_control_other                          int64
# pest_control_chemical_materials_cost      float64
# pest_control_workers_count                  int64
# pest_control_worker_wage_per_day            int64
# pest_control_working_days                   int64
# pest_control_labor_total_cost               int64
# pest_control_grand_total_cost               int64
# water_meter_reading                         int64
# water_pumping_hours_per_irrigation          int64
# water_irrigation_frequency_per_month        int64
# water_calculated_hours_per_month          float64
# water_diesel_cost                           int64
# water_workers_count                         int64
# water_worker_wage_per_day                   int64
# water_working_days_per_month                int64
# water_labor_total_cost                      int64
# water_grand_total_cost                      int64
# water_pumping_mechanism_type               object
# water_engine_hours_per_acre_per_day         int64
# water_diesel_quantity_last_month            int64
# water_diesel_cost_last_month                int64
# surveyor_notes                             object
# record_index                                int64
# dtype: object

# %%
df.drop(columns=['surveyor_notes'], inplace=True)

# %%
df['survey_date'] = pd.to_datetime(df['survey_date'])

# %%
df.to_excel('Irrigation_DS_Clean.xlsx', index=False)
