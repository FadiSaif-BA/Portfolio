# %% [markdown]
# # 📊 Irrigation Dataset - Exploratory Data Analysis (EDA)
#
# This notebook performs comprehensive exploratory data analysis on the irrigation survey dataset.
#
# **Dataset**: `Irrigation_DS.xlsx`
# **Rows**: 30 survey responses
# **Columns**: 70 variables covering survey metadata, land preparation, cultivation, fertilization, production, pest control, and water consumption
#
# ---

# %% [markdown]
# ## 1. Setup and Data Loading

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings

# Configure display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.2f}'.format)
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print("✓ Libraries imported successfully!")
# Out:
# ✓ Libraries imported successfully!

# %%
# Load the dataset
df = pd.read_excel('Irrigation_DS_Clean.xlsx')

print("✓ Dataset loaded successfully!")
print(f"\nDataset shape: {df.shape[0]} rows × {df.shape[1]} columns")
# Out:
# ✓ Dataset loaded successfully!
#
# Dataset shape: 30 rows × 55 columns

# %% [markdown]
# ## 2. Data Overview

# %%
# Display first few rows
print("First 5 rows of the dataset:")
print("=" * 100)
display(df.head())
# Out:
# First 5 rows of the dataset:
# ====================================================================================================
#   survey_date governorate district  village_name irrigation_system_type  \
# 0  2020-01-07        Lahj    Tuban  كدمه عوض علي            Traditional
# 1  2020-01-27        Lahj    Tuban       بئر فضل                   Drip
# 2  2020-01-08        Lahj    Tuban        كوكبان            Traditional
# 3  2020-01-08        Lahj    Tuban     هران ديان                   Drip
# 4  2020-01-08        Lahj    Tuban       الحمراء                   Drip
#
#   crop_type  land_prep_plowing_cost_per_acre  \
# 0  Eggplant                            42000
# 1  Eggplant                                0
# 2    Tomato                            14000
# 3    Tomato                            24000
# 4    pepper                            24000
#
#    land_prep_settlement_cost_per_acre  land_prep_division_cost_per_acre  \
# 0                               16000                             16000
# 1                                   0                                 0
# 2                               28000                             14000
# 3                               21000                             14000
# 4                               21000                                 0
#
#    land_prep_terracing_cost_per_acre  land_prep_total_cost  \
# 0                              12000                 86000
# 1                                  0                     0
# 2                              14000                 70000
# 3                                  0                 59000
# 4                                  0                 45000
#
#    land_prep_workers_count  land_prep_worker_wage_per_day  \
# 0                        8                           1500
# 1                        0                              0
# 2                        4                           4000
# 3                        0                              0
# 4                        0                              0
#
#    land_prep_working_days  land_prep_labor_total_cost  \
# 0                       1                       12000
# 1                       0                           0
# 2                       1                       16000
# 3                       0                           0
# 4                       0                           0
#
#    land_prep_grand_total_cost  nursery_prep_total_cost  \
# 0                       98000                   120000
# 1                           0                   120000
# 2                       86000                   120000
# 3                       59000                   120000
# 4                       45000                   120000
#
#    cultivation_laborers_count  cultivation_seeds_quantity  \
# 0                           2                        2000
# 1                           2                        2000
# 2                           2                        4000
# 3                           6                        3000
# 4                           3                        1500
#
#    cultivation_worker_wage_per_day  cultivation_labor_total_cost  \
# 0                                1                          4000
# 1                                1                          4000
# 2                                2                         16000
# 3                                2                         36000
# 4                                2                          9000
#
#    fertilizer_quantity_kg  fertilizer_cost_yer  fertilizer_total_cost  \
# 0                      25                  720                  18000
# 1                       0                    0                      0
# 2                      70                  700                  49000
# 3                      60                  750                  45000
# 4                      50                  700                  35000
#
#    production_quantity_baskets_kg  production_harvest_frequency_per_month  \
# 0                          120.00                                    1.00
# 1                            0.00                                    1.00
# 2                         3200.00                                    5.00
# 3                          800.00                                    1.00
# 4                         2000.00                                    3.00
#
#    production_total_harvest_cost  production_harvest_labor_cost  \
# 0                            250                          30000
# 1                              0                              0
# 2                            150                         480000
# 3                            150                         120000
# 4                            200                         400000
#
#    production_final_harvest_cost_yer  \
# 0                           15000.00
# 1                               0.00
# 2                          410000.00
# 3                           14000.00
# 4                          202800.00
#
#                                    pest_control_type  pest_control_biological  \
# 0                مكافحة كيمياوية (باستخدام المبيدات)                        0
# 1  اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل ...                        0
# 2                مكافحة كيمياوية (باستخدام المبيدات)                        0
# 3                مكافحة كيمياوية (باستخدام المبيدات)                        0
# 4                مكافحة كيمياوية (باستخدام المبيدات)                        0
#
#    pest_control_mechanical  pest_control_chemical  pest_control_other  \
# 0                        0                      1                   0
# 1                        0                      0                   1
# 2                        0                      1                   0
# 3                        0                      1                   0
# 4                        0                      1                   0
#
#    pest_control_chemical_materials_cost  pest_control_workers_count  \
# 0                              10000.00                           2
# 1                                   NaN                           2
# 2                              63000.00                           3
# 3                              28000.00                           1
# 4                              51000.00                           3
#
#    pest_control_worker_wage_per_day  pest_control_working_days  \
# 0                              4000                          2
# 1                              2000                          6
# 2                              3000                          3
# 3                              3000                          4
# 4                              2000                          3
#
#    pest_control_labor_total_cost  pest_control_grand_total_cost  \
# 0                          16000                          26000
# 1                          24000                          24000
# 2                          27000                          90000
# 3                          12000                          40000
# 4                          18000                          69000
#
#    water_meter_reading  water_pumping_hours_per_irrigation  \
# 0                  294                                  12
# 1                  115                                   2
# 2                  343                                  16
# 3                  147                                   4
# 4                  169                                   4
#
#    water_irrigation_frequency_per_month  water_calculated_hours_per_month  \
# 0                                     4                            160.00
# 1                                    10                             66.70
# 2                                     7                            373.30
# 3                                    15                            200.00
# 4                                     8                            106.70
#
#    water_diesel_cost  water_workers_count  water_worker_wage_per_day  \
# 0              64000                    2                       5000
# 1              26680                    1                       2000
# 2             149320                    2                       2500
# 3              80000                    1                       3000
# 4              42680                    1                       2000
#
#    water_working_days_per_month  water_labor_total_cost  \
# 0                             4                   40000
# 1                            10                   20000
# 2                             7                   35000
# 3                            10                   30000
# 4                             8                   16000
#
#    water_grand_total_cost water_pumping_mechanism_type  \
# 0                  104000                 مضخات الديزل
# 1                   46680                 مضخات الديزل
# 2                  184320                 مضخات الديزل
# 3                  110000                 مضخات الديزل
# 4                   58680                 مضخات كهرباء
#
#    water_engine_hours_per_acre_per_day  water_diesel_quantity_last_month  \
# 0                                   12                               100
# 1                                    2                                40
# 2                                   18                               280
# 3                                    4                               160
# 4                                    4                                 0
#
#    water_diesel_cost_last_month  record_index
# 0                         64000            11
# 1                         16000            22
# 2                        112000            13
# 3                         60000            16
# 4                         10000            15

# %%
# Display last few rows
print("Last 5 rows of the dataset:")
print("=" * 100)
display(df.tail())
# Out:
# Last 5 rows of the dataset:
# ====================================================================================================
#    survey_date governorate district village_name irrigation_system_type  \
# 25  2020-01-30        Lahj    Tuban        طهرور                   Drip
# 26  2020-01-27        Lahj    Tuban        المحط                   Drip
# 27  2020-01-28        Lahj    Tuban       الفيوش                   Drip
# 28  2020-01-29        Lahj    Tuban      الحمراء                   Drip
# 29  2020-01-27        Lahj    Tuban      بئر فضل                   Drip
#
#    crop_type  land_prep_plowing_cost_per_acre  \
# 25     Onion                                0
# 26     Onion                                0
# 27     Onion                                0
# 28     Onion                                0
# 29     Onion                                0
#
#     land_prep_settlement_cost_per_acre  land_prep_division_cost_per_acre  \
# 25                                   0                                 0
# 26                                   0                                 0
# 27                                   0                                 0
# 28                                   0                                 0
# 29                                   0                                 0
#
#     land_prep_terracing_cost_per_acre  land_prep_total_cost  \
# 25                                  0                     0
# 26                                  0                     0
# 27                                  0                     0
# 28                                  0                     0
# 29                                  0                     0
#
#     land_prep_workers_count  land_prep_worker_wage_per_day  \
# 25                        0                              0
# 26                        0                              0
# 27                        0                              0
# 28                        0                              0
# 29                        0                              0
#
#     land_prep_working_days  land_prep_labor_total_cost  \
# 25                       0                           0
# 26                       0                           0
# 27                       0                           0
# 28                       0                           0
# 29                       0                           0
#
#     land_prep_grand_total_cost  nursery_prep_total_cost  \
# 25                           0                   120000
# 26                           0                   120000
# 27                           0                   120000
# 28                           0                   120000
# 29                           0                   120000
#
#     cultivation_laborers_count  cultivation_seeds_quantity  \
# 25                           4                        2000
# 26                           4                        2000
# 27                           4                        2000
# 28                           4                        2000
# 29                           4                        2000
#
#     cultivation_worker_wage_per_day  cultivation_labor_total_cost  \
# 25                                5                         40000
# 26                                4                         32000
# 27                                4                         32000
# 28                                4                         32000
# 29                                4                         32000
#
#     fertilizer_quantity_kg  fertilizer_cost_yer  fertilizer_total_cost  \
# 25                     120                  700                  84000
# 26                       0                    0                      0
# 27                       0                    0                      0
# 28                      70                  740                  51800
# 29                       0                    0                      0
#
#     production_quantity_baskets_kg  production_harvest_frequency_per_month  \
# 25                            0.00                                    0.00
# 26                            0.00                                    0.00
# 27                            0.00                                    0.00
# 28                            0.00                                    0.00
# 29                            0.00                                    0.00
#
#     production_total_harvest_cost  production_harvest_labor_cost  \
# 25                              0                              0
# 26                              0                              0
# 27                              0                              0
# 28                              0                              0
# 29                              0                              0
#
#     production_final_harvest_cost_yer  \
# 25                               0.00
# 26                               0.00
# 27                               0.00
# 28                               0.00
# 29                               0.00
#
#                                     pest_control_type  \
# 25  اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل ...
# 26  اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل ...
# 27                مكافحة كيمياوية (باستخدام المبيدات)
# 28                مكافحة كيمياوية (باستخدام المبيدات)
# 29  اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل ...
#
#     pest_control_biological  pest_control_mechanical  pest_control_chemical  \
# 25                        0                        0                      0
# 26                        0                        0                      0
# 27                        0                        0                      1
# 28                        0                        0                      1
# 29                        0                        0                      0
#
#     pest_control_other  pest_control_chemical_materials_cost  \
# 25                   1                                   NaN
# 26                   1                                   NaN
# 27                   0                              15000.00
# 28                   0                              17000.00
# 29                   1                                   NaN
#
#     pest_control_workers_count  pest_control_worker_wage_per_day  \
# 25                           2                              2000
# 26                           0                                 0
# 27                           1                              3000
# 28                           2                              2000
# 29                           0                                 0
#
#     pest_control_working_days  pest_control_labor_total_cost  \
# 25                          3                          12000
# 26                          0                              0
# 27                          3                           9000
# 28                          1                           4000
# 29                          0                              0
#
#     pest_control_grand_total_cost  water_meter_reading  \
# 25                          12000                   70
# 26                              0                   19
# 27                          24000                   96
# 28                          21000                  104
# 29                              0                   32
#
#     water_pumping_hours_per_irrigation  water_irrigation_frequency_per_month  \
# 25                                   3                                    10
# 26                                   2                                     8
# 27                                   4                                     8
# 28                                   3                                     8
# 29                                   2                                    10
#
#     water_calculated_hours_per_month  water_diesel_cost  water_workers_count  \
# 25                            100.00              40000                    1
# 26                             53.30              21320                    1
# 27                            106.70              42680                    1
# 28                             80.00              32000                    1
# 29                             66.70              26680                    1
#
#     water_worker_wage_per_day  water_working_days_per_month  \
# 25                       2000                            10
# 26                       2000                             8
# 27                       3000                             8
# 28                       3000                             3
# 29                       2000                            10
#
#     water_labor_total_cost  water_grand_total_cost  \
# 25                   20000                   60000
# 26                   16000                   37320
# 27                   24000                   66680
# 28                    9000                   41000
# 29                   20000                   46680
#
#    water_pumping_mechanism_type  water_engine_hours_per_acre_per_day  \
# 25                 مضخات الديزل                                    3
# 26                 مضخات الديزل                                    2
# 27                 مضخات كهرباء                                    4
# 28                 مضخات الديزل                                    3
# 29                 مضخات الديزل                                    2
#
#     water_diesel_quantity_last_month  water_diesel_cost_last_month  \
# 25                               110                         45000
# 26                                40                            16
# 27                                 0                             0
# 28                                80                         30000
# 29                                40                         16000
#
#     record_index
# 25            46
# 26            24
# 27            30
# 28            36
# 29            23

# %%
# Basic information
print("Dataset Information:")
print("=" * 100)
print(df.info())
# Out:
# Dataset Information:
# ====================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   survey_date                             30 non-null     datetime64[ns]
#  1   governorate                             30 non-null     object
#  2   district                                30 non-null     object
#  3   village_name                            30 non-null     object
#  4   irrigation_system_type                  30 non-null     object
#  5   crop_type                               30 non-null     object
#  6   land_prep_plowing_cost_per_acre         30 non-null     int64
#  7   land_prep_settlement_cost_per_acre      30 non-null     int64
#  8   land_prep_division_cost_per_acre        30 non-null     int64
#  9   land_prep_terracing_cost_per_acre       30 non-null     int64
#  10  land_prep_total_cost                    30 non-null     int64
#  11  land_prep_workers_count                 30 non-null     int64
#  12  land_prep_worker_wage_per_day           30 non-null     int64
#  13  land_prep_working_days                  30 non-null     int64
#  14  land_prep_labor_total_cost              30 non-null     int64
#  15  land_prep_grand_total_cost              30 non-null     int64
#  16  nursery_prep_total_cost                 30 non-null     int64
#  17  cultivation_laborers_count              30 non-null     int64
#  18  cultivation_seeds_quantity              30 non-null     int64
#  19  cultivation_worker_wage_per_day         30 non-null     int64
#  20  cultivation_labor_total_cost            30 non-null     int64
#  21  fertilizer_quantity_kg                  30 non-null     int64
#  22  fertilizer_cost_yer                     30 non-null     int64
#  23  fertilizer_total_cost                   30 non-null     int64
#  24  production_quantity_baskets_kg          28 non-null     float64
#  25  production_harvest_frequency_per_month  28 non-null     float64
#  26  production_total_harvest_cost           30 non-null     int64
#  27  production_harvest_labor_cost           30 non-null     int64
#  28  production_final_harvest_cost_yer       28 non-null     float64
#  29  pest_control_type                       30 non-null     object
#  30  pest_control_biological                 30 non-null     int64
#  31  pest_control_mechanical                 30 non-null     int64
#  32  pest_control_chemical                   30 non-null     int64
#  33  pest_control_other                      30 non-null     int64
#  34  pest_control_chemical_materials_cost    19 non-null     float64
#  35  pest_control_workers_count              30 non-null     int64
#  36  pest_control_worker_wage_per_day        30 non-null     int64
#  37  pest_control_working_days               30 non-null     int64
#  38  pest_control_labor_total_cost           30 non-null     int64
#  39  pest_control_grand_total_cost           30 non-null     int64
#  40  water_meter_reading                     30 non-null     int64
#  41  water_pumping_hours_per_irrigation      30 non-null     int64
#  42  water_irrigation_frequency_per_month    30 non-null     int64
#  43  water_calculated_hours_per_month        30 non-null     float64
#  44  water_diesel_cost                       30 non-null     int64
#  45  water_workers_count                     30 non-null     int64
#  46  water_worker_wage_per_day               30 non-null     int64
#  47  water_working_days_per_month            30 non-null     int64
#  48  water_labor_total_cost                  30 non-null     int64
#  49  water_grand_total_cost                  30 non-null     int64
#  50  water_pumping_mechanism_type            30 non-null     object
#  51  water_engine_hours_per_acre_per_day     30 non-null     int64
#  52  water_diesel_quantity_last_month        30 non-null     int64
#  53  water_diesel_cost_last_month            30 non-null     int64
#  54  record_index                            30 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(42), object(7)
# memory usage: 13.0+ KB
# None

# %%
# Column names organized by section
print("Column Organization:")
print("=" * 100)

sections = {
    'Survey Metadata': [col for col in df.columns if col.startswith(('survey_', 'surveyor_', 'governorate', 'village_', 'beneficiary_', 'respondent_'))],
    'Farm Information': [col for col in df.columns if col.startswith(('irrigation_', 'crop_'))],
    'Land Preparation': [col for col in df.columns if col.startswith('Land_Prep_')],
    'Nursery': [col for col in df.columns if col.startswith('nursery_')],
    'Cultivation': [col for col in df.columns if col.startswith('cultivation_')],
    'Fertilization': [col for col in df.columns if col.startswith('fertiliz')],
    'Production': [col for col in df.columns if col.startswith('production_')],
    'Pest Control': [col for col in df.columns if col.startswith('pest_')],
    'Water': [col for col in df.columns if col.startswith('water_')],
}

for section, cols in sections.items():
    if cols:
        print(f"\n{section}: {len(cols)} columns")
# Out:
# Column Organization:
# ====================================================================================================
#
# Survey Metadata: 3 columns
#
# Farm Information: 2 columns
#
# Nursery: 1 columns
#
# Cultivation: 4 columns
#
# Fertilization: 3 columns
#
# Production: 5 columns
#
# Pest Control: 11 columns
#
# Water: 14 columns

# %% [markdown]
# ## 3. Data Quality Assessment

# %%
# Check for missing values
print("Missing Values Analysis:")
print("=" * 100)

missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': missing.index,
    'Missing_Count': missing.values,
    'Missing_Percentage': missing_pct.values
})

# Show only columns with missing values
missing_cols = missing_df[missing_df['Missing_Count'] > 0].sort_values('Missing_Count', ascending=False)

if len(missing_cols) > 0:
    print(f"\nColumns with missing values: {len(missing_cols)}")
    display(missing_cols)
else:
    print("\n✓ No missing values found in the dataset!")

print(f"\nTotal missing values: {missing.sum()}")
print(f"Percentage of complete rows: {(df.notnull().all(axis=1).sum() / len(df) * 100):.2f}%")
# Out:
# Missing Values Analysis:
# ====================================================================================================
#
# Columns with missing values: 4
#                                     Column  Missing_Count  Missing_Percentage
# 34    pest_control_chemical_materials_cost             11               36.67
# 24          production_quantity_baskets_kg              2                6.67
# 25  production_harvest_frequency_per_month              2                6.67
# 28       production_final_harvest_cost_yer              2                6.67
# Total missing values: 17
# Percentage of complete rows: 56.67%

# %%
# Check for duplicate rows
print("Duplicate Rows Check:")
print("=" * 100)

duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")

if duplicates > 0:
    print("\nDuplicate rows:")
    display(df[df.duplicated(keep=False)])
else:
    print("✓ No duplicate rows found!")
# Out:
# Duplicate Rows Check:
# ====================================================================================================
#
# Number of duplicate rows: 0
# ✓ No duplicate rows found!

# %%
# Data types summary
print("Data Types Summary:")
print("=" * 100)

dtype_counts = df.dtypes.value_counts()
print("\nColumn count by data type:")
print(dtype_counts)

# Identify numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
datetime_cols = df.select_dtypes(include=['datetime64']).columns.tolist()

print(f"\nNumeric columns: {len(numeric_cols)}")
print(f"Categorical columns: {len(categorical_cols)}")
print(f"DateTime columns: {len(datetime_cols)}")
# Out:
# Data Types Summary:
# ====================================================================================================
#
# Column count by data type:
# int64             42
# object             7
# float64            5
# datetime64[ns]     1
# Name: count, dtype: int64
#
# Numeric columns: 47
# Categorical columns: 7
# DateTime columns: 1

# %% [markdown]
# ## 4. Descriptive Statistics

# %%
# Numerical columns statistics
print("Descriptive Statistics for Numerical Columns:")
print("=" * 100)

display(df.describe().T)
# Out:
# Descriptive Statistics for Numerical Columns:
# ====================================================================================================
#                                        count                 mean  \
# survey_date                               30  2020-01-14 21:36:00
# land_prep_plowing_cost_per_acre        30.00             15600.00
# land_prep_settlement_cost_per_acre     30.00             12850.00
# land_prep_division_cost_per_acre       30.00              5866.67
# land_prep_terracing_cost_per_acre      30.00              5016.67
# land_prep_total_cost                   30.00             39333.33
# land_prep_workers_count                30.00                 1.47
# land_prep_worker_wage_per_day          30.00              1450.00
# land_prep_working_days                 30.00                 0.80
# land_prep_labor_total_cost             30.00             10133.33
# land_prep_grand_total_cost             30.00             49466.67
# nursery_prep_total_cost                30.00             77920.00
# cultivation_laborers_count             30.00                 3.77
# cultivation_seeds_quantity             30.00              2220.00
# cultivation_worker_wage_per_day        30.00                 2.87
# cultivation_labor_total_cost           30.00             23936.67
# fertilizer_quantity_kg                 30.00                54.83
# fertilizer_cost_yer                    30.00               538.67
# fertilizer_total_cost                  30.00             39973.33
# production_quantity_baskets_kg         28.00              1964.46
# production_harvest_frequency_per_month 28.00                 0.96
# production_total_harvest_cost          30.00                79.33
# production_harvest_labor_cost          30.00            279990.00
# production_final_harvest_cost_yer      28.00            177650.00
# pest_control_biological                30.00                 0.00
# pest_control_mechanical                30.00                 0.00
# pest_control_chemical                  30.00                 0.67
# pest_control_other                     30.00                 0.50
# pest_control_chemical_materials_cost   19.00             29210.53
# pest_control_workers_count             30.00                 1.67
# pest_control_worker_wage_per_day       30.00              2173.33
# pest_control_working_days              30.00                 1.87
# pest_control_labor_total_cost          30.00             10513.33
# pest_control_grand_total_cost          30.00             29013.33
# water_meter_reading                    30.00               339.47
# water_pumping_hours_per_irrigation     30.00                 6.90
# water_irrigation_frequency_per_month   30.00                 7.37
# water_calculated_hours_per_month       30.00               132.23
# water_diesel_cost                      30.00             52890.67
# water_workers_count                    30.00                 1.40
# water_worker_wage_per_day              30.00              2666.67
# water_working_days_per_month           30.00                 7.13
# water_labor_total_cost                 30.00             23966.67
# water_grand_total_cost                 30.00             76857.33
# water_engine_hours_per_acre_per_day    30.00                 7.23
# water_diesel_quantity_last_month       30.00                83.67
# water_diesel_cost_last_month           30.00             54767.20
# record_index                           30.00                18.27
#
#                                                         min  \
# survey_date                             2020-01-06 00:00:00
# land_prep_plowing_cost_per_acre                        0.00
# land_prep_settlement_cost_per_acre                     0.00
# land_prep_division_cost_per_acre                       0.00
# land_prep_terracing_cost_per_acre                      0.00
# land_prep_total_cost                                   0.00
# land_prep_workers_count                                0.00
# land_prep_worker_wage_per_day                          0.00
# land_prep_working_days                                 0.00
# land_prep_labor_total_cost                             0.00
# land_prep_grand_total_cost                             0.00
# nursery_prep_total_cost                             6000.00
# cultivation_laborers_count                             1.00
# cultivation_seeds_quantity                          1000.00
# cultivation_worker_wage_per_day                        1.00
# cultivation_labor_total_cost                        3000.00
# fertilizer_quantity_kg                                 0.00
# fertilizer_cost_yer                                    0.00
# fertilizer_total_cost                                  0.00
# production_quantity_baskets_kg                         0.00
# production_harvest_frequency_per_month                 0.00
# production_total_harvest_cost                          0.00
# production_harvest_labor_cost                          0.00
# production_final_harvest_cost_yer                      0.00
# pest_control_biological                                0.00
# pest_control_mechanical                                0.00
# pest_control_chemical                                  0.00
# pest_control_other                                     0.00
# pest_control_chemical_materials_cost                5000.00
# pest_control_workers_count                             0.00
# pest_control_worker_wage_per_day                       0.00
# pest_control_working_days                              0.00
# pest_control_labor_total_cost                          0.00
# pest_control_grand_total_cost                          0.00
# water_meter_reading                                   19.00
# water_pumping_hours_per_irrigation                     2.00
# water_irrigation_frequency_per_month                   2.00
# water_calculated_hours_per_month                      26.70
# water_diesel_cost                                  10680.00
# water_workers_count                                    1.00
# water_worker_wage_per_day                           1000.00
# water_working_days_per_month                           2.00
# water_labor_total_cost                              4000.00
# water_grand_total_cost                             14680.00
# water_engine_hours_per_acre_per_day                    2.00
# water_diesel_quantity_last_month                       0.00
# water_diesel_cost_last_month                           0.00
# record_index                                           1.00
#
#                                                         25%  \
# survey_date                             2020-01-07 00:00:00
# land_prep_plowing_cost_per_acre                        0.00
# land_prep_settlement_cost_per_acre                     0.00
# land_prep_division_cost_per_acre                       0.00
# land_prep_terracing_cost_per_acre                      0.00
# land_prep_total_cost                                   0.00
# land_prep_workers_count                                0.00
# land_prep_worker_wage_per_day                          0.00
# land_prep_working_days                                 0.00
# land_prep_labor_total_cost                             0.00
# land_prep_grand_total_cost                             0.00
# nursery_prep_total_cost                            20000.00
# cultivation_laborers_count                             3.00
# cultivation_seeds_quantity                          1500.00
# cultivation_worker_wage_per_day                        2.00
# cultivation_labor_total_cost                       12000.00
# fertilizer_quantity_kg                                 5.00
# fertilizer_cost_yer                                  170.00
# fertilizer_total_cost                               3500.00
# production_quantity_baskets_kg                         0.00
# production_harvest_frequency_per_month                 0.00
# production_total_harvest_cost                          0.00
# production_harvest_labor_cost                          0.00
# production_final_harvest_cost_yer                      0.00
# pest_control_biological                                0.00
# pest_control_mechanical                                0.00
# pest_control_chemical                                  0.00
# pest_control_other                                     0.00
# pest_control_chemical_materials_cost                9500.00
# pest_control_workers_count                             1.00
# pest_control_worker_wage_per_day                    2000.00
# pest_control_working_days                              1.00
# pest_control_labor_total_cost                       2000.00
# pest_control_grand_total_cost                       6250.00
# water_meter_reading                                   62.25
# water_pumping_hours_per_irrigation                     3.00
# water_irrigation_frequency_per_month                   4.00
# water_calculated_hours_per_month                      80.00
# water_diesel_cost                                  32000.00
# water_workers_count                                    1.00
# water_worker_wage_per_day                           2000.00
# water_working_days_per_month                           4.00
# water_labor_total_cost                             12000.00
# water_grand_total_cost                             47750.00
# water_engine_hours_per_acre_per_day                    3.00
# water_diesel_quantity_last_month                       2.50
# water_diesel_cost_last_month                       16000.00
# record_index                                           8.25
#
#                                                         50%  \
# survey_date                             2020-01-08 00:00:00
# land_prep_plowing_cost_per_acre                    15000.00
# land_prep_settlement_cost_per_acre                 12000.00
# land_prep_division_cost_per_acre                       0.00
# land_prep_terracing_cost_per_acre                      0.00
# land_prep_total_cost                               30000.00
# land_prep_workers_count                                0.00
# land_prep_worker_wage_per_day                          0.00
# land_prep_working_days                                 0.00
# land_prep_labor_total_cost                             0.00
# land_prep_grand_total_cost                         30000.00
# nursery_prep_total_cost                           120000.00
# cultivation_laborers_count                             4.00
# cultivation_seeds_quantity                          2000.00
# cultivation_worker_wage_per_day                        2.50
# cultivation_labor_total_cost                       22050.00
# fertilizer_quantity_kg                                50.00
# fertilizer_cost_yer                                  700.00
# fertilizer_total_cost                              35000.00
# production_quantity_baskets_kg                        97.50
# production_harvest_frequency_per_month                 1.00
# production_total_harvest_cost                         50.00
# production_harvest_labor_cost                       3750.00
# production_final_harvest_cost_yer                  14500.00
# pest_control_biological                                0.00
# pest_control_mechanical                                0.00
# pest_control_chemical                                  1.00
# pest_control_other                                     0.50
# pest_control_chemical_materials_cost               26000.00
# pest_control_workers_count                             2.00
# pest_control_worker_wage_per_day                    2000.00
# pest_control_working_days                              2.00
# pest_control_labor_total_cost                       8000.00
# pest_control_grand_total_cost                      22500.00
# water_meter_reading                                  119.50
# water_pumping_hours_per_irrigation                     4.00
# water_irrigation_frequency_per_month                   6.50
# water_calculated_hours_per_month                     113.35
# water_diesel_cost                                  45340.00
# water_workers_count                                    1.00
# water_worker_wage_per_day                           2250.00
# water_working_days_per_month                           6.00
# water_labor_total_cost                             20000.00
# water_grand_total_cost                             65340.00
# water_engine_hours_per_acre_per_day                    4.00
# water_diesel_quantity_last_month                      60.00
# water_diesel_cost_last_month                       40000.00
# record_index                                          16.50
#
#                                                         75%  \
# survey_date                             2020-01-27 18:00:00
# land_prep_plowing_cost_per_acre                    24000.00
# land_prep_settlement_cost_per_acre                 20250.00
# land_prep_division_cost_per_acre                   10000.00
# land_prep_terracing_cost_per_acre                   8000.00
# land_prep_total_cost                               67250.00
# land_prep_workers_count                                3.50
# land_prep_worker_wage_per_day                       3000.00
# land_prep_working_days                                 1.00
# land_prep_labor_total_cost                         19000.00
# land_prep_grand_total_cost                         82625.00
# nursery_prep_total_cost                           120000.00
# cultivation_laborers_count                             4.00
# cultivation_seeds_quantity                          3000.00
# cultivation_worker_wage_per_day                        4.00
# cultivation_labor_total_cost                       32000.00
# fertilizer_quantity_kg                                70.00
# fertilizer_cost_yer                                  740.00
# fertilizer_total_cost                              51350.00
# production_quantity_baskets_kg                       350.00
# production_harvest_frequency_per_month                 1.00
# production_total_harvest_cost                        150.00
# production_harvest_labor_cost                      39800.00
# production_final_harvest_cost_yer                  50000.00
# pest_control_biological                                0.00
# pest_control_mechanical                                0.00
# pest_control_chemical                                  1.00
# pest_control_other                                     1.00
# pest_control_chemical_materials_cost               38000.00
# pest_control_workers_count                             2.75
# pest_control_worker_wage_per_day                    3000.00
# pest_control_working_days                              3.00
# pest_control_labor_total_cost                      17500.00
# pest_control_grand_total_cost                      41500.00
# water_meter_reading                                  330.75
# water_pumping_hours_per_irrigation                    11.25
# water_irrigation_frequency_per_month                  10.00
# water_calculated_hours_per_month                     160.00
# water_diesel_cost                                  64000.00
# water_workers_count                                    2.00
# water_worker_wage_per_day                           3000.00
# water_working_days_per_month                          10.00
# water_labor_total_cost                             31500.00
# water_grand_total_cost                            101750.00
# water_engine_hours_per_acre_per_day                    9.75
# water_diesel_quantity_last_month                     120.00
# water_diesel_cost_last_month                       59000.00
# record_index                                          26.25
#
#                                                         max       std
# survey_date                             2020-01-30 00:00:00       NaN
# land_prep_plowing_cost_per_acre                    48000.00  14623.08
# land_prep_settlement_cost_per_acre                 56000.00  13473.57
# land_prep_division_cost_per_acre                   48000.00   9950.68
# land_prep_terracing_cost_per_acre                  32000.00   8761.68
# land_prep_total_cost                              136000.00  39299.54
# land_prep_workers_count                                8.00      2.27
# land_prep_worker_wage_per_day                       5000.00   2060.93
# land_prep_working_days                                 4.00      1.24
# land_prep_labor_total_cost                         54000.00  15954.10
# land_prep_grand_total_cost                        173000.00  52379.24
# nursery_prep_total_cost                           210000.00  55817.30
# cultivation_laborers_count                             9.00      1.72
# cultivation_seeds_quantity                          5000.00    947.74
# cultivation_worker_wage_per_day                        6.00      1.43
# cultivation_labor_total_cost                       90000.00  19459.85
# fertilizer_quantity_kg                               200.00     54.50
# fertilizer_cost_yer                                 1000.00    335.05
# fertilizer_total_cost                             144000.00  39314.72
# production_quantity_baskets_kg                     24000.00   5404.86
# production_harvest_frequency_per_month                 5.00      1.20
# production_total_harvest_cost                        280.00     89.94
# production_harvest_labor_cost                    3600000.00 785868.58
# production_final_harvest_cost_yer                3272000.00 624818.56
# pest_control_biological                                0.00      0.00
# pest_control_mechanical                                0.00      0.00
# pest_control_chemical                                  1.00      0.48
# pest_control_other                                     1.00      0.51
# pest_control_chemical_materials_cost               80000.00  23272.73
# pest_control_workers_count                             3.00      1.06
# pest_control_worker_wage_per_day                    5000.00   1304.35
# pest_control_working_days                              6.00      1.38
# pest_control_labor_total_cost                      27000.00   9803.68
# pest_control_grand_total_cost                     107000.00  30625.75
# water_meter_reading                                 2051.00    549.83
# water_pumping_hours_per_irrigation                    16.00      4.96
# water_irrigation_frequency_per_month                  15.00      4.08
# water_calculated_hours_per_month                     373.30     77.46
# water_diesel_cost                                 149320.00  30982.81
# water_workers_count                                    4.00      0.72
# water_worker_wage_per_day                           5000.00   1085.43
# water_working_days_per_month                          15.00      3.86
# water_labor_total_cost                             90000.00  17590.13
# water_grand_total_cost                            184320.00  41625.78
# water_engine_hours_per_acre_per_day                   24.00      5.83
# water_diesel_quantity_last_month                     320.00     86.12
# water_diesel_cost_last_month                      510000.00  91766.12
# record_index                                          47.00     12.77

# %%
# Categorical columns summary
print("Categorical Variables Summary:")
print("=" * 100)

for col in categorical_cols[:10]:  # Show first 10 categorical columns
    if col in df.columns:
        print(f"\n{col}:")
        print("-" * 80)
        print(f"Unique values: {df[col].nunique()}")
        print(f"\nValue counts:")
        print(df[col].value_counts())
# Out:
# Categorical Variables Summary:
# ====================================================================================================
#
# governorate:
# --------------------------------------------------------------------------------
# Unique values: 1
#
# Value counts:
# governorate
# Lahj    30
# Name: count, dtype: int64
#
# district:
# --------------------------------------------------------------------------------
# Unique values: 1
#
# Value counts:
# district
# Tuban    30
# Name: count, dtype: int64
#
# village_name:
# --------------------------------------------------------------------------------
# Unique values: 16
#
# Value counts:
# village_name
# الوهط           5
# كدمه عوض علي    3
# الحمراء         3
# دار المناصرة    3
# هران ديان       2
# كوكبان          2
# بئر فضل         2
# طهرور           2
# الحاسكي         1
# الصمصام         1
# صبر             1
# جول اليماني     1
# الكدام          1
# عبربدر          1
# المحط           1
# الفيوش          1
# Name: count, dtype: int64
#
# irrigation_system_type:
# --------------------------------------------------------------------------------
# Unique values: 2
#
# Value counts:
# irrigation_system_type
# Traditional    15
# Drip           15
# Name: count, dtype: int64
#
# crop_type:
# --------------------------------------------------------------------------------
# Unique values: 5
#
# Value counts:
# crop_type
# Onion          14
# Leafy plant     6
# pepper          6
# Eggplant        2
# Tomato          2
# Name: count, dtype: int64
#
# pest_control_type:
# --------------------------------------------------------------------------------
# Unique values: 3
#
# Value counts:
# pest_control_type
# مكافحة كيمياوية (باستخدام المبيدات)                                                                                                                             15
# اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)                                        14
# مكافحة كيمياوية (باستخدام المبيدات) اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)     1
# Name: count, dtype: int64
#
# water_pumping_mechanism_type:
# --------------------------------------------------------------------------------
# Unique values: 2
#
# Value counts:
# water_pumping_mechanism_type
# مضخات الديزل    22
# مضخات كهرباء     8
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Survey Metadata Analysis

# %%
# Survey metadata overview
print("Survey Metadata Overview:")
print("=" * 100)

metadata_cols = ['Surveyor_Name', 'Survey_Date', 'Governorate', 'Governorate_Lahj', 'Village_Name']
existing_metadata = [col for col in metadata_cols if col in df.columns]

if existing_metadata:
    display(df[existing_metadata].head(10))
# Out:
# Survey Metadata Overview:
# ====================================================================================================

# %%
# Village distribution
if 'village_name' in df.columns:
    print("Surveys per Village:")
    print("=" * 100)
    
    village_counts = df['village_name'].value_counts()
    print(village_counts)
    
    # Visualization
    plt.figure(figsize=(12, 6))
    village_counts.plot(kind='barh', color='forestgreen')
    plt.title('Number of Surveys per Village', fontsize=14, fontweight='bold')
    plt.xlabel('Number of Surveys')
    plt.ylabel('Village Name')
    plt.tight_layout()
    plt.show()
# Out:
# Surveys per Village:
# ====================================================================================================
# village_name
# الوهط           5
# كدمه عوض علي    3
# الحمراء         3
# دار المناصرة    3
# هران ديان       2
# كوكبان          2
# بئر فضل         2
# طهرور           2
# الحاسكي         1
# الصمصام         1
# صبر             1
# جول اليماني     1
# الكدام          1
# عبربدر          1
# المحط           1
# الفيوش          1
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Farm Information Analysis

# %%
# Crop type distribution
if 'crop_type' in df.columns:
    print("Crop Type Distribution:")
    print("=" * 100)
    
    crop_counts = df['crop_type'].value_counts()
    print(crop_counts)
    
    # Visualization - Pie chart
    plt.figure(figsize=(7, 6))
    colors = plt.cm.Set3(range(len(crop_counts)))
    plt.pie(crop_counts.values, labels=crop_counts.index, autopct='%1.1f%%', 
            startangle=90, colors=colors)
    plt.title('Distribution of Crop Types', fontsize=14, fontweight='bold')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
# Out:
# Crop Type Distribution:
# ====================================================================================================
# crop_type
# Onion          14
# Leafy plant     6
# pepper          6
# Eggplant        2
# Tomato          2
# Name: count, dtype: int64

# %%
# Irrigation system distribution
if 'irrigation_system_type' in df.columns:
    print("Irrigation System Type Distribution:")
    print("=" * 100)
    
    irrigation_counts = df['irrigation_system_type'].value_counts()
    print(irrigation_counts)
    
    # Visualization
    plt.figure(figsize=(10, 6))
    irrigation_counts.plot(kind='bar', color=['#2E86AB', '#A23B72'])
    plt.title('Distribution of Irrigation System Types', fontsize=14, fontweight='bold')
    plt.xlabel('Irrigation System Type')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Irrigation System Type Distribution:
# ====================================================================================================
# irrigation_system_type
# Traditional    15
# Drip           15
# Name: count, dtype: int64

# %%
# Crop type vs Irrigation system
if 'crop_type' in df.columns and 'irrigation_system_type' in df.columns:
    print("Crop Type vs Irrigation System Cross-tabulation:")
    print("=" * 100)
    
    crosstab = pd.crosstab(df['crop_type'], df['irrigation_system_type'], margins=True)
    display(crosstab)
    
    # Visualization - Grouped bar chart
    crosstab_plot = pd.crosstab(df['crop_type'], df['irrigation_system_type'])
    
    plt.figure(figsize=(12, 6))
    crosstab_plot.plot(kind='bar', stacked=False, color=['#2E86AB', '#A23B72'])
    plt.title('Crop Types by Irrigation System', fontsize=14, fontweight='bold')
    plt.xlabel('Crop Type')
    plt.ylabel('Count')
    plt.legend(title='Irrigation System')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Crop Type vs Irrigation System Cross-tabulation:
# ====================================================================================================
# irrigation_system_type  Drip  Traditional  All
# crop_type
# Eggplant                   1            1    2
# Leafy plant                3            3    6
# Onion                      7            7   14
# Tomato                     1            1    2
# pepper                     3            3    6
# All                       15           15   30

# %% [markdown]
# ## 7. Cost Analysis

# %%
# Identify all cost columns
cost_columns = [col for col in df.columns if 'cost' in col or 'cost' in col.lower()]

print(f"Cost-related columns found: {len(cost_columns)}")
print("=" * 100)

# Filter to numeric cost columns
numeric_cost_cols = [col for col in cost_columns if col in numeric_cols]
print(f"\nNumeric cost columns: {len(numeric_cost_cols)}")

for col in numeric_cost_cols[:10]:  # Show first 10
    print(f"  • {col}")
# Out:
# Cost-related columns found: 21
# ====================================================================================================
#
# Numeric cost columns: 21
#   • land_prep_plowing_cost_per_acre
#   • land_prep_settlement_cost_per_acre
#   • land_prep_division_cost_per_acre
#   • land_prep_terracing_cost_per_acre
#   • land_prep_total_cost
#   • land_prep_labor_total_cost
#   • land_prep_grand_total_cost
#   • nursery_prep_total_cost
#   • cultivation_labor_total_cost
#   • fertilizer_cost_yer

# %%
# Summary statistics for major cost categories
major_costs = [
    'land_prep_grand_total_cost',
    'fertilizer_total_cost',
    'pest_control_grand_total_cost',
    'water_grand_total_cost'
]

existing_major_costs = [col for col in major_costs if col in df.columns]

if existing_major_costs:
    print("Major Cost Categories - Summary Statistics:")
    print("=" * 100)
    display(df[existing_major_costs].describe())
# Out:
# Major Cost Categories - Summary Statistics:
# ====================================================================================================
#        land_prep_grand_total_cost  fertilizer_total_cost  \
# count                       30.00                  30.00
# mean                     49466.67               39973.33
# std                      52379.24               39314.72
# min                          0.00                   0.00
# 25%                          0.00                3500.00
# 50%                      30000.00               35000.00
# 75%                      82625.00               51350.00
# max                     173000.00              144000.00
#
#        pest_control_grand_total_cost  water_grand_total_cost
# count                          30.00                   30.00
# mean                        29013.33                76857.33
# std                         30625.75                41625.78
# min                             0.00                14680.00
# 25%                          6250.00                47750.00
# 50%                         22500.00                65340.00
# 75%                         41500.00               101750.00
# max                        107000.00               184320.00

# %%
# Average costs by irrigation system
if 'irrigation_system_type' in df.columns and existing_major_costs:
    print("Average Costs by Irrigation System Type:")
    print("=" * 100)
    
    cost_by_irrigation = df.groupby('irrigation_system_type')[existing_major_costs].mean()
    display(cost_by_irrigation)
    
    # Visualization
    cost_by_irrigation.T.plot(kind='bar', figsize=(12, 6))
    plt.title('Average Costs by Irrigation System Type', fontsize=14, fontweight='bold')
    plt.xlabel('Cost Category')
    plt.ylabel('Average Cost (YER)')
    plt.legend(title='Irrigation System')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Average Costs by Irrigation System Type:
# ====================================================================================================
#                         land_prep_grand_total_cost  fertilizer_total_cost  \
# irrigation_system_type
# Drip                                      21733.33               25380.00
# Traditional                               77200.00               54566.67
#
#                         pest_control_grand_total_cost  water_grand_total_cost
# irrigation_system_type
# Drip                                         22133.33                70826.67
# Traditional                                  35893.33                82888.00

# %%
# Average costs by crop type
if 'crop_type' in df.columns and existing_major_costs:
    print("Average Costs by Crop Type:")
    print("=" * 100)
    
    cost_by_crop = df.groupby('crop_type')[existing_major_costs].mean()
    display(cost_by_crop)
    
    # Visualization
    cost_by_crop.T.plot(kind='bar', figsize=(14, 6))
    plt.title('Average Costs by Crop Type', fontsize=14, fontweight='bold')
    plt.xlabel('Cost Category')
    plt.ylabel('Average Cost (YER)')
    plt.legend(title='Crop Type', bbox_to_anchor=(1.05, 1))
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Average Costs by Crop Type:
# ====================================================================================================
#              land_prep_grand_total_cost  fertilizer_total_cost  \
# crop_type
# Eggplant                       49000.00                9000.00
# Leafy plant                    52166.67               20250.00
# Onion                          57071.43               44628.57
# Tomato                         72500.00               47000.00
# pepper                         21500.00               56816.67
#
#              pest_control_grand_total_cost  water_grand_total_cost
# crop_type
# Eggplant                          25000.00                75340.00
# Leafy plant                        5833.33                72446.67
# Onion                             35428.57                71977.14
# Tomato                            65000.00               147160.00
# pepper                            26566.67                69726.67

# %% [markdown]
# ## 8. Distribution Analysis

# %%
# Distribution of major cost categories
if existing_major_costs:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    fig.suptitle('Distribution of Major Cost Categories', fontsize=16, fontweight='bold')
    
    for idx, col in enumerate(existing_major_costs[:4]):
        ax = axes[idx // 2, idx % 2]
        df[col].hist(bins=15, ax=ax, color='skyblue', edgecolor='black')
        ax.set_title(col.replace('_', ' '), fontweight='bold')
        ax.set_xlabel('Cost (YER)')
        ax.set_ylabel('Frequency')
        ax.axvline(df[col].mean(), color='red', linestyle='--', linewidth=2, label='Mean')
        ax.axvline(df[col].median(), color='green', linestyle='--', linewidth=2, label='Median')
        ax.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Box plots for cost categories
if existing_major_costs:
    plt.figure(figsize=(14, 6))
    df[existing_major_costs].boxplot()
    plt.title('Box Plot of Major Cost Categories', fontsize=14, fontweight='bold')
    plt.ylabel('Cost (YER)')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Water Consumption Analysis

# %%
# Water-related metrics
water_metrics = [
    'water_pumping_hours_per_irrigation',
    'water_irrigation_frequency_per_month',
    'water_diesel_cost',
    'water_grand_total_cost'
]

existing_water_metrics = [col for col in water_metrics if col in df.columns]

if existing_water_metrics:
    print("Water Consumption Metrics - Summary:")
    print("=" * 100)
    display(df[existing_water_metrics].describe())
# Out:
# Water Consumption Metrics - Summary:
# ====================================================================================================
#        water_pumping_hours_per_irrigation  \
# count                               30.00
# mean                                 6.90
# std                                  4.96
# min                                  2.00
# 25%                                  3.00
# 50%                                  4.00
# 75%                                 11.25
# max                                 16.00
#
#        water_irrigation_frequency_per_month  water_diesel_cost  \
# count                                 30.00              30.00
# mean                                   7.37           52890.67
# std                                    4.08           30982.81
# min                                    2.00           10680.00
# 25%                                    4.00           32000.00
# 50%                                    6.50           45340.00
# 75%                                   10.00           64000.00
# max                                   15.00          149320.00
#
#        water_grand_total_cost
# count                   30.00
# mean                 76857.33
# std                  41625.78
# min                  14680.00
# 25%                  47750.00
# 50%                  65340.00
# 75%                 101750.00
# max                 184320.00

# %%
# Water consumption by irrigation system
if 'irrigation_system_type' in df.columns and existing_water_metrics:
    print("Water Metrics by Irrigation System Type:")
    print("=" * 100)
    
    water_by_system = df.groupby('irrigation_system_type')[existing_water_metrics].mean()
    display(water_by_system)
    
    # Visualization
    water_by_system.T.plot(kind='bar', figsize=(12, 6))
    plt.title('Average Water Metrics by Irrigation System', fontsize=14, fontweight='bold')
    plt.xlabel('Metric')
    plt.ylabel('Average Value')
    plt.legend(title='Irrigation System')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Water Metrics by Irrigation System Type:
# ====================================================================================================
#                         water_pumping_hours_per_irrigation  \
# irrigation_system_type
# Drip                                                  3.47
# Traditional                                          10.33
#
#                         water_irrigation_frequency_per_month  \
# irrigation_system_type
# Drip                                                   10.53
# Traditional                                             4.20
#
#                         water_diesel_cost  water_grand_total_cost
# irrigation_system_type
# Drip                             47026.67                70826.67
# Traditional                      58754.67                82888.00

# %% [markdown]
# ## 10. Production Analysis

# %%
# Production metrics
production_metrics = [
    'production_quantity_baskets_kg',
    'production_harvest_frequency_per_month',
    'production_total_harvest_cost'
]

existing_prod_metrics = [col for col in production_metrics if col in df.columns]

if existing_prod_metrics:
    print("Production Metrics - Summary:")
    print("=" * 100)
    display(df[existing_prod_metrics].describe())
# Out:
# Production Metrics - Summary:
# ====================================================================================================
#        production_quantity_baskets_kg  production_harvest_frequency_per_month  \
# count                           28.00                                   28.00
# mean                          1964.46                                    0.96
# std                           5404.86                                    1.20
# min                              0.00                                    0.00
# 25%                              0.00                                    0.00
# 50%                             97.50                                    1.00
# 75%                            350.00                                    1.00
# max                          24000.00                                    5.00
#
#        production_total_harvest_cost
# count                          30.00
# mean                           79.33
# std                            89.94
# min                             0.00
# 25%                             0.00
# 50%                            50.00
# 75%                           150.00
# max                           280.00

# %%
# Production by crop type
if 'crop_type' in df.columns and existing_prod_metrics:
    print("Production Metrics by Crop Type:")
    print("=" * 100)
    
    prod_by_crop = df.groupby('crop_type')[existing_prod_metrics].mean()
    display(prod_by_crop)
    
    # Visualization
    prod_by_crop.plot(kind='bar', figsize=(12, 6), subplots=True, layout=(1, 3), 
                      legend=False, sharex=False)
    plt.suptitle('Production Metrics by Crop Type', fontsize=14, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.show()
# Out:
# Production Metrics by Crop Type:
# ====================================================================================================
#              production_quantity_baskets_kg  \
# crop_type
# Eggplant                              60.00
# Leafy plant                          114.17
# Onion                               3615.38
# Tomato                              2000.00
# pepper                               640.00
#
#              production_harvest_frequency_per_month  \
# crop_type
# Eggplant                                       1.00
# Leafy plant                                    1.00
# Onion                                          0.23
# Tomato                                         3.00
# pepper                                         2.00
#
#              production_total_harvest_cost
# crop_type
# Eggplant                            125.00
# Leafy plant                          83.33
# Onion                                32.14
# Tomato                              150.00
# pepper                              146.67

# %% [markdown]
# ## 11. Correlation Analysis

# %%
# Correlation matrix for cost-related columns
if len(numeric_cost_cols) > 1:
    # Select subset of meaningful cost columns
    key_cost_cols = [col for col in existing_major_costs if col in df.columns]
    
    if len(key_cost_cols) > 1:
        print("Correlation Matrix - Major Cost Categories:")
        print("=" * 100)
        
        correlation = df[key_cost_cols].corr()
        display(correlation)
        
        # Heatmap
        plt.figure(figsize=(10, 8))
        sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', 
                    center=0, square=True, linewidths=1)
        plt.title('Correlation Heatmap - Major Cost Categories', fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.show()
# Out:
# Correlation Matrix - Major Cost Categories:
# ====================================================================================================
#                                land_prep_grand_total_cost  \
# land_prep_grand_total_cost                           1.00
# fertilizer_total_cost                                0.35
# pest_control_grand_total_cost                        0.71
# water_grand_total_cost                               0.46
#
#                                fertilizer_total_cost  \
# land_prep_grand_total_cost                      0.35
# fertilizer_total_cost                           1.00
# pest_control_grand_total_cost                   0.53
# water_grand_total_cost                          0.16
#
#                                pest_control_grand_total_cost  \
# land_prep_grand_total_cost                              0.71
# fertilizer_total_cost                                   0.53
# pest_control_grand_total_cost                           1.00
# water_grand_total_cost                                  0.54
#
#                                water_grand_total_cost
# land_prep_grand_total_cost                       0.46
# fertilizer_total_cost                            0.16
# pest_control_grand_total_cost                    0.54
# water_grand_total_cost                           1.00

# %% [markdown]
# ## 12. Key Insights and Findings

# %%
print("=" * 100)
print("KEY INSIGHTS FROM EDA")
print("=" * 100)

insights = []

# Dataset overview
insights.append(f"\n📊 Dataset Overview:")
insights.append(f"   • Total survey responses: {len(df)}")
insights.append(f"   • Total variables measured: {len(df.columns)}")
insights.append(f"   • Data completeness: {(df.notnull().all(axis=1).sum() / len(df) * 100):.1f}% of rows complete")

# Crop diversity
if 'crop_type' in df.columns:
    insights.append(f"\n🌾 Crop Diversity:")
    insights.append(f"   • Number of different crops: {df['crop_type'].nunique()}")
    insights.append(f"   • Most common crop: {df['crop_type'].mode()[0]} ({df['crop_type'].value_counts().iloc[0]} farms)")

# Irrigation systems
if 'irrigation_system_type' in df.columns:
    insights.append(f"\n💧 Irrigation Systems:")
    for system, count in df['irrigation_system_type'].value_counts().items():
        pct = (count / len(df)) * 100
        insights.append(f"   • {system}: {count} farms ({pct:.1f}%)")

# Cost insights
if existing_major_costs:
    insights.append(f"\n💰 Cost Insights:")
    for col in existing_major_costs:
        if col in df.columns:
            avg_cost = df[col].mean()
            insights.append(f"   • Average {col.replace('_', ' ')}: {avg_cost:,.0f} YER")

# Print all insights
for insight in insights:
    print(insight)

print("\n" + "=" * 100)
# Out:
# ====================================================================================================
# KEY INSIGHTS FROM EDA
# ====================================================================================================
#
# 📊 Dataset Overview:
#    • Total survey responses: 30
#    • Total variables measured: 55
#    • Data completeness: 56.7% of rows complete
#
# 🌾 Crop Diversity:
#    • Number of different crops: 5
#    • Most common crop: Onion (14 farms)
#
# 💧 Irrigation Systems:
#    • Traditional: 15 farms (50.0%)
#    • Drip: 15 farms (50.0%)
#
# 💰 Cost Insights:
#    • Average land prep grand total cost: 49,467 YER
#    • Average fertilizer total cost: 39,973 YER
#    • Average pest control grand total cost: 29,013 YER
#    • Average water grand total cost: 76,857 YER
#
# ====================================================================================================

# %% [markdown]
# ## 13. Summary and Recommendations

# %% [markdown]
# ### 📌 Summary of EDA
#
# This exploratory data analysis covered:
#
# 1. **Data Quality**: Assessed completeness, duplicates, and data types
# 2. **Survey Overview**: Distribution of surveys by surveyor, village, and date
# 3. **Farm Characteristics**: Crop types and irrigation systems in use
# 4. **Cost Analysis**: Breakdown of costs across different farming activities
# 5. **Water Usage**: Analysis of water consumption and irrigation patterns
# 6. **Production**: Harvest quantities and frequencies by crop type
# 7. **Correlations**: Relationships between different cost categories
#
# ### 🎯 Next Steps
#
# Based on this EDA, recommended analyses:
#
# 1. **Cost-Benefit Analysis**: Compare total costs vs production output by irrigation system
# 2. **Efficiency Metrics**: Calculate cost per kg of production for each crop/system combination
# 3. **Water Efficiency**: Analyze water consumption relative to production output
# 4. **Predictive Modeling**: Build models to predict production costs based on farm characteristics
# 5. **Optimization**: Identify best practices from high-performing farms
#
# ### 📈 Potential Visualizations
#
# - Geographic mapping of farms (if coordinates available)
# - Time series analysis of survey dates
# - Interactive dashboards for cost comparisons
# - Sankey diagrams showing cost breakdowns
#
# ---
#
# **End of Exploratory Data Analysis** 🎉
