# %%
import pandas as pd
import numpy as np

# %%
# load dataset as dataframe
irrigation = pd.read_excel('Irrigation_DS.xlsx')

# %%
# explore data
irrigation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 70 columns):
#  #   Column                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                 --------------  -----
#  0   start                                                                                                                                                  30 non-null     object
#  1   end                                                                                                                                                    30 non-null     object
#  2   اسم الماسح:                                                                                                                                            30 non-null     object
#  3   تاريخ المسح                                                                                                                                            30 non-null     object
#  4   المحافظة                                                                                                                                               30 non-null     object
#  5   المحافظة: لحج                                                                                                                                          30 non-null     object
#  6   القرية                                                                                                                                                 30 non-null     object
#  7   اسم المستفيد                                                                                                                                           30 non-null     object
#  8   اسم المستجيب                                                                                                                                           30 non-null     object
#  9    Type of Irrigation system                                                                                                                             30 non-null     object
#  10  Type of crop growing                                                                                                                                   30 non-null     object
#  11   اولا: اعداد الارض:(ساعات*اجرة)                                                                                                                        30 non-null     object
#  12  total cost take to plow the area of ​​ one acre connected to the meter?                                                                                30 non-null     int64
#  13  total cost take to settle the area of one acre                                                                                                         30 non-null     int64
#  14  total cost take to divide the area of ​​one acre connected to the meter?                                                                               30 non-null     int64
#  15  total cost take to terrace the area of one acre connected to the meter?                                                                                30 non-null     int64
#  16  total_cost                                                                                                                                             30 non-null     int64
#  17  How many workers were needed to raise the terracing and canals                                                                                         30 non-null     int64
#  18  How much was the wage of a worker per day per acre connected to the meter                                                                              30 non-null     int64
#  19  How many days were needed to work on this acre?                                                                                                        30 non-null     int64
#  20  total cost of worker to prepare the land                                                                                                               30 non-null     int64
#  21  Total cost of Land prepare                                                                                                                             30 non-null     int64
#  22    ثانيا: اعداد المشتل                                                                                                                                  30 non-null     object
#  23  total cost of seeding preparing                                                                                                                        30 non-null     int64
#  24  ثالثا: زراعة الارض المستديمة: *يتم اجراء هذا المسح في الشهر الاول و الثاني                                                                             30 non-null     object
#  25  How many labors were needed to cultivate one acre of …………………… (tomatoes / onions / green jalapino / Leafy plants / okra)                               30 non-null     int64
#  26  How much was the cost of seeds / seedlings planted per acre: The amount of seeds (Quantity)                                                            30 non-null     int64
#  27  How much was the wage of a worker per day?                                                                                                             30 non-null     int64
#  28  The cost of the worker in cultivating sustainable land                                                                                                 30 non-null     int64
#  29  Fertilization                                                                                                                                          30 non-null     object
#  30  How much was the cost of the fertilizer you used in the one acer connected to the meter? (Quantity in kg)                                              30 non-null     int64
#  31  How much was the cost of the fertilizer you used in the one acer connected to the meter? (Cost (YER))                                                  30 non-null     int64
#  32  Total cost of fertilizer                                                                                                                               30 non-null     int64
#  33  خامسا: Quantity of production and harvest                                                                                                              30 non-null     object
#  34  Quantity of production in the last cultivation season (number of baskets / kg)                                                                         28 non-null     float64
#  35  How many times did you harvest the planted items in the last month?                                                                                    28 non-null     float64
#  36  الكلفة العامة لكمية المحصول                                                                                                                            30 non-null     int64
#  37  cost of  production and harvest                                                                                                                        30 non-null     int64
#  38  سادسا: Cost of production:                                                                                                                             30 non-null     object
#  39  How much was the final production cost needed for harvesting in YER                                                                                    28 non-null     float64
#  40  سابعا:Pest Control                                                                                                                                     30 non-null     object
#  41   ماهو نوع المكافحة المستخدمة                                                                                                                           30 non-null     object
#  42   ماهو نوع المكافحة المستخدمة/مكافحة حيوية (استخدام الاعداء الطبيعية منها: المفترسات و المتطفلات مثل النمل)                                             30 non-null     int64
#  43   ماهو نوع المكافحة المستخدمة/مكافحة ميكانيكية (جمع الحشرات الكبيرة باليد وا ستخدام التدخين واستخدام المصائد الضوئية و الفورمونية)                      30 non-null     int64
#  44   ماهو نوع المكافحة المستخدمة/مكافحة كيمياوية (باستخدام المبيدات)                                                                                       30 non-null     int64
#  45   ماهو نوع المكافحة المستخدمة/اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)  30 non-null     int64
#  46  If the answer (chemical control) how much was the cost of its materials:                                                                               19 non-null     float64
#  47  How many workers were needed?                                                                                                                          30 non-null     int64
#  48  How much was the wage of the worker per day?                                                                                                           30 non-null     int64
#  49  no. of working day                                                                                                                                     30 non-null     int64
#  50  worker cost of pest control                                                                                                                            30 non-null     int64
#  51  Total cost of Pest control                                                                                                                             30 non-null     int64
#  52   ثامنا: Amount of water consumed                                                                                                                       30 non-null     object
#  53  Record the meters reading                                                                                                                              30 non-null     int64
#  54  How many hours the water pumped in one irrigation time?                                                                                                30 non-null     int64
#  55  How many times the land was irrigated in the last month?                                                                                               30 non-null     int64
#  56  Hr*time per month/6*20                                                                                                                                 30 non-null     float64
#  57  cost of desile                                                                                                                                         30 non-null     int64
#  58  no of worker needed to irrigate the land                                                                                                               30 non-null     int64
#  59  wage of worker per day                                                                                                                                 30 non-null     int64
#  60  no of days per month                                                                                                                                   30 non-null     int64
#  61  total cost of worker                                                                                                                                   30 non-null     int64
#  62  Total cost of water and diesel consumption                                                                                                             30 non-null     int64
#  63                                                                                                                                                         30 non-null     object
#  64  What is the applied pumping mechanism                                                                                                                  30 non-null     object
#  65  The number of hours were needed to operate the engine to irrigate the acre per day:                                                                    30 non-null     int64
#  66  What was the amount of diesel spent to irrigate the area of the acre in the last month?                                                                30 non-null     int64
#  67  How much was the cost of diesel spent in the last month?                                                                                               30 non-null     int64
#  68  ملاحظات الماسح                                                                                                                                         30 non-null     object
#  69  _index                                                                                                                                                 30 non-null     int64
# dtypes: float64(5), int64(42), object(23)
# memory usage: 16.5+ KB

# %%
irrigation.columns.tolist()
# Out:
# ['start',
#  'end',
#  'اسم الماسح:',
#  'تاريخ المسح',
#  'المحافظة',
#  'المحافظة: لحج',
#  'القرية',
#  'اسم المستفيد',
#  'اسم المستجيب',
#  ' Type of Irrigation system',
#  'Type of crop growing',
#  ' اولا: اعداد الارض:(ساعات*اجرة) ',
#  'total cost take to plow the area of \u200b\u200b one acre connected to the meter?',
#  'total cost take to settle the area of one acre',
#  'total cost take to divide the area of \u200b\u200bone acre connected to the meter?',
#  'total cost take to terrace the area of one acre connected to the meter?',
#  'total_cost',
#  'How many workers were needed to raise the terracing and canals ',
#  'How much was the wage of a worker per day per acre connected to the meter',
#  'How many days were needed to work on this acre?',
#  'total cost of worker to prepare the land',
#  'Total cost of Land prepare',
#  '  ثانيا: اعداد المشتل  ',
#  'total cost of seeding preparing',
#  'ثالثا: زراعة الارض المستديمة: *يتم اجراء هذا المسح في الشهر الاول و الثاني',
#  'How many labors were needed to cultivate one acre of …………………… (tomatoes / onions / green jalapino / Leafy plants / okra) ',
#  'How much was the cost of seeds / seedlings planted per acre: The amount of seeds (Quantity)',
#  'How much was the wage of a worker per day?',
#  'The cost of the worker in cultivating sustainable land',
#  'Fertilization',
#  'How much was the cost of the fertilizer you used in the one acer connected to the meter? (Quantity in kg)',
#  'How much was the cost of the fertilizer you used in the one acer connected to the meter? (Cost (YER))',
#  'Total cost of fertilizer ',
#  'خامسا: Quantity of production and harvest',
#  'Quantity of production in the last cultivation season (number of baskets / kg)',
#  'How many times did you harvest the planted items in the last month? ',
#  'الكلفة العامة لكمية المحصول',
#  'cost of  production and harvest',
#  'سادسا: Cost of production: ',
#  'How much was the final production cost needed for harvesting in YER',
#  'سابعا:Pest Control',
#  ' ماهو نوع المكافحة المستخدمة',
#  ' ماهو نوع المكافحة المستخدمة/مكافحة حيوية (استخدام الاعداء الطبيعية منها: المفترسات و المتطفلات مثل النمل)',
#  ' ماهو نوع المكافحة المستخدمة/مكافحة ميكانيكية (جمع الحشرات الكبيرة باليد وا ستخدام التدخين واستخدام المصائد الضوئية و الفورمونية)',
#  ' ماهو نوع المكافحة المستخدمة/مكافحة كيمياوية (باستخدام المبيدات)',
#  ' ماهو نوع المكافحة المستخدمة/اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)',
#  'If the answer (chemical control) how much was the cost of its materials:',
#  'How many workers were needed?',
#  'How much was the wage of the worker per day?',
#  'no. of working day',
#  'worker cost of pest control',
#  'Total cost of Pest control',
#  ' ثامنا: Amount of water consumed',
#  'Record the meters reading',
#  'How many hours the water pumped in one irrigation time?',
#  'How many times the land was irrigated in the last month?',
#  'Hr*time per month/6*20',
#  'cost of desile',
#  'no of worker needed to irrigate the land',
#  'wage of worker per day',
#  'no of days per month',
#  'total cost of worker',
#  'Total cost of water and diesel consumption',
#  '      ',
#  'What is the applied pumping mechanism',
#  'The number of hours were needed to operate the engine to irrigate the acre per day:',
#  'What was the amount of diesel spent to irrigate the area of the acre in the last month?',
#  'How much was the cost of diesel spent in the last month?',
#  'ملاحظات الماسح',
#  '_index']

# %%
irrigation.head(5)
# Out:
#                            start                            end اسم الماسح:  \
# 0  2020-01-07T23:46:15.606+03:00  2020-01-07T23:56:55.363+03:00       سيلان
# 1  2020-01-27T09:05:52.930+03:00  2020-01-28T23:22:19.978+03:00       سوزان
# 2  2020-01-08T08:54:56.638+03:00  2020-01-08T09:28:00.559+03:00       اسرار
# 3  2020-01-08T10:50:42.269+03:00  2020-01-08T11:30:17.610+03:00       اسرار
# 4  2020-01-08T10:09:23.398+03:00  2020-01-08T10:50:30.498+03:00       اسرار
#
#   تاريخ المسح المحافظة المحافظة: لحج        القرية  \
# 0  2020-01-07      لحج           تبن  كدمه عوض علي
# 1  2020-01-27      لحج           تبن       بئر فضل
# 2  2020-01-08      لحج           تبن        كوكبان
# 3  2020-01-08      لحج           تبن     هران ديان
# 4  2020-01-08      لحج           تبن       الحمراء
#
#                   اسم المستفيد         اسم المستجيب  \
# 0               نبيل قائد معين       نبيل قائد معين
# 1        مختار حيدره علي حيدره       محسن علي حيدره
# 2          صادق محمد فضل العسر  صادق محمد فضل العسر
# 3          قيصر سبيت ناصر سبيت  قيصر سبيت ناصر سبيت
# 4  ارسلان عبدالله ناصر حيدرة\n  ارسلان عبدالله ناصر
#
#    Type of Irrigation system  ... no of days per month total cost of worker  \
# 0                Traditional  ...                    4                40000
# 1                       Drip  ...                   10                20000
# 2                Traditional  ...                    7                35000
# 3                       Drip  ...                   10                30000
# 4                       Drip  ...                    8                16000
#
#    Total cost of water and diesel consumption          \
# 0                                      104000      OK
# 1                                       46680      OK
# 2                                      184320      OK
# 3                                      110000      OK
# 4                                       58680      OK
#
#    What is the applied pumping mechanism  \
# 0                           مضخات الديزل
# 1                           مضخات الديزل
# 2                           مضخات الديزل
# 3                           مضخات الديزل
# 4                           مضخات كهرباء
#
#    The number of hours were needed to operate the engine to irrigate the acre per day:  \
# 0                                                 12
# 1                                                  2
# 2                                                 18
# 3                                                  4
# 4                                                  4
#
#    What was the amount of diesel spent to irrigate the area of the acre in the last month?  \
# 0                                                100
# 1                                                 40
# 2                                                280
# 3                                                160
# 4                                                  0
#
#    How much was the cost of diesel spent in the last month?  \
# 0                                              64000
# 1                                              16000
# 2                                             112000
# 3                                              60000
# 4                                              10000
#
#                                       ملاحظات الماسح  _index
# 0  المحصول جيد والمزارع مثابر ونفذ جميع عمليات ال...      11
# 1  المزارع استفاد من شبكة التنقيط وزرع و وفرت تكل...      22
# 2  بدا جني المحصول والمزارع مهتم بعمليات مكافكة ا...      13
# 3            المزارع مثالي برغم الآفات الا انه يكافح      16
# 4  المزارع مثالي بدأ جني المحصول والنمو جيد المزا...      15
#
# [5 rows x 70 columns]

# %%
# Display current columns
print("=" * 60)
print("CURRENT COLUMN NAMES:")
print("=" * 60)
for i, col in enumerate(irrigation.columns, 1):
    print(f"{i}. {col}")

print(f"\nTotal columns: {len(irrigation.columns)}")
print(f"Total rows: {len(irrigation)}")

# Display first few rows to understand data
print("\n" + "=" * 60)
print("FIRST 3 ROWS OF DATA:")
print("=" * 60)
print(irrigation.head(3))

# Show data types
print("\n" + "=" * 60)
print("COLUMN DATA TYPES:")
print("=" * 60)
print(irrigation.dtypes)
# Out:
# ============================================================
# CURRENT COLUMN NAMES:
# ============================================================
# 1. start
# 2. end
# 3. اسم الماسح:
# 4. تاريخ المسح
# 5. المحافظة
# 6. المحافظة: لحج
# 7. القرية
# 8. اسم المستفيد
# 9. اسم المستجيب
# 10.  Type of Irrigation system
# 11. Type of crop growing
# 12.  اولا: اعداد الارض:(ساعات*اجرة)
# 13. total cost take to plow the area of ​​ one acre connected to the meter?
# 14. total cost take to settle the area of one acre
# 15. total cost take to divide the area of ​​one acre connected to the meter?
# 16. total cost take to terrace the area of one acre connected to the meter?
# 17. total_cost
# 18. How many workers were needed to raise the terracing and canals
# 19. How much was the wage of a worker per day per acre connected to the meter
# 20. How many days were needed to work on this acre?
# 21. total cost of worker to prepare the land
# 22. Total cost of Land prepare
# 23.   ثانيا: اعداد المشتل
# 24. total cost of seeding preparing
# 25. ثالثا: زراعة الارض المستديمة: *يتم اجراء هذا المسح في الشهر الاول و الثاني
# 26. How many labors were needed to cultivate one acre of …………………… (tomatoes / onions / green jalapino / Leafy plants / okra)
# 27. How much was the cost of seeds / seedlings planted per acre: The amount of seeds (Quantity)
# 28. How much was the wage of a worker per day?
# 29. The cost of the worker in cultivating sustainable land
# 30. Fertilization
# 31. How much was the cost of the fertilizer you used in the one acer connected to the meter? (Quantity in kg)
# 32. How much was the cost of the fertilizer you used in the one acer connected to the meter? (Cost (YER))
# 33. Total cost of fertilizer
# 34. خامسا: Quantity of production and harvest
# 35. Quantity of production in the last cultivation season (number of baskets / kg)
# 36. How many times did you harvest the planted items in the last month?
# 37. الكلفة العامة لكمية المحصول
# 38. cost of  production and harvest
# 39. سادسا: Cost of production:
# 40. How much was the final production cost needed for harvesting in YER
# 41. سابعا:Pest Control
# 42.  ماهو نوع المكافحة المستخدمة
# 43.  ماهو نوع المكافحة المستخدمة/مكافحة حيوية (استخدام الاعداء الطبيعية منها: المفترسات و المتطفلات مثل النمل)
# 44.  ماهو نوع المكافحة المستخدمة/مكافحة ميكانيكية (جمع الحشرات الكبيرة باليد وا ستخدام التدخين واستخدام المصائد الضوئية و الفورمونية)
# 45.  ماهو نوع المكافحة المستخدمة/مكافحة كيمياوية (باستخدام المبيدات)
# 46.  ماهو نوع المكافحة المستخدمة/اخرى(باستخدام الدورة الزراعية, خدمة الارض مثل تقليب الارض/ ازالة الحشائش / الري والتسميد/ زراعة الاصناف المقاومة للافات)
# 47. If the answer (chemical control) how much was the cost of its materials:
# 48. How many workers were needed?
# 49. How much was the wage of the worker per day?
# 50. no. of working day
# 51. worker cost of pest control
# 52. Total cost of Pest control
# 53.  ثامنا: Amount of water consumed
# 54. Record the meters reading
# 55. How many hours the water pumped in one irrigation time?
# 56. How many times the land was irrigated in the last month?
# 57. Hr*time per month/6*20
# 58. cost of desile
# 59. no of worker needed to irrigate the land
# 60. wage of worker per day
# 61. no of days per month
# 62. total cost of worker
# 63. Total cost of water and diesel consumption
# 64.
# 65. What is the applied pumping mechanism
# 66. The number of hours were needed to operate the engine to irrigate the acre per day:
# 67. What was the amount of diesel spent to irrigate the area of the acre in the last month?
# 68. How much was the cost of diesel spent in the last month?
# 69. ملاحظات الماسح
# 70. _index
#
# Total columns: 70
# Total rows: 30
#
# ============================================================
# FIRST 3 ROWS OF DATA:
# ============================================================
#                            start                            end اسم الماسح:  \
# 0  2020-01-07T23:46:15.606+03:00  2020-01-07T23:56:55.363+03:00       سيلان
# 1  2020-01-27T09:05:52.930+03:00  2020-01-28T23:22:19.978+03:00       سوزان
# 2  2020-01-08T08:54:56.638+03:00  2020-01-08T09:28:00.559+03:00       اسرار
#
#   تاريخ المسح المحافظة المحافظة: لحج        القرية           اسم المستفيد  \
# 0  2020-01-07      لحج           تبن  كدمه عوض علي         نبيل قائد معين
# 1  2020-01-27      لحج           تبن       بئر فضل  مختار حيدره علي حيدره
# 2  2020-01-08      لحج           تبن        كوكبان    صادق محمد فضل العسر
#
#           اسم المستجيب  Type of Irrigation system  ... no of days per month  \
# 0       نبيل قائد معين                Traditional  ...                    4
# 1       محسن علي حيدره                       Drip  ...                   10
# 2  صادق محمد فضل العسر                Traditional  ...                    7
#
#   total cost of worker  Total cost of water and diesel consumption          \
# 0                40000                                      104000      OK
# 1                20000                                       46680      OK
# 2                35000                                      184320      OK
#
#    What is the applied pumping mechanism  \
# 0                           مضخات الديزل
# 1                           مضخات الديزل
# 2                           مضخات الديزل
#
#    The number of hours were needed to operate the engine to irrigate the acre per day:  \
# 0                                                 12
# 1                                                  2
# 2                                                 18
#
#    What was the amount of diesel spent to irrigate the area of the acre in the last month?  \
# 0                                                100
# 1                                                 40
# 2                                                280
#
#    How much was the cost of diesel spent in the last month?  \
# 0                                              64000
# 1                                              16000
# 2                                             112000
#
#                                       ملاحظات الماسح  _index
# 0  المحصول جيد والمزارع مثابر ونفذ جميع عمليات ال...      11
# 1  المزارع استفاد من شبكة التنقيط وزرع و وفرت تكل...      22
# 2  بدا جني المحصول والمزارع مهتم بعمليات مكافكة ا...      13
#
# [3 rows x 70 columns]
#
# ============================================================
# COLUMN DATA TYPES:
# ============================================================
# start                                                                                      object
# end                                                                                        object
# اسم الماسح:                                                                                object
# تاريخ المسح                                                                                object
# المحافظة                                                                                   object
#                                                                                             ...
# The number of hours were needed to operate the engine to irrigate the acre per day:         int64
# What was the amount of diesel spent to irrigate the area of the acre in the last month?     int64
# How much was the cost of diesel spent in the last month?                                    int64
# ملاحظات الماسح                                                                             object
# _index                                                                                      int64
# Length: 70, dtype: object
